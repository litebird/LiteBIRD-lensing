# %%
import numpy as np, pickle
from matplotlib.pyplot import *

# %%
root  = '/global/cscratch1/sd/lonappan/S4BIRD/DELL_noisefix/s1d1/Reconstruction_2_600/'
fnlkk = root + 'MCN0_500_fsky_0.80.pkl'
frlkk = root + 'response_fsky_0.80_mean.pkl'

# %%
N0 = pickle.load(open(fnlkk,"rb"))
R0 = pickle.load(open(frlkk,"rb"))

# %%
Lmax = 1024
L = np.linspace(0,Lmax,Lmax+1)

# %%
# noise spectrum of phi
xlim(1,Lmax)
loglog(L,N0/R0**2)
# Out:
# /global/homes/t/toshiyan/.conda/envs/loc/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# transform to noise spectrum of kappa
ylim(1e-7,1e-4)
loglog(L,(L*(L+1)*.5)**2*N0/R0**2)
# Out:
# /global/homes/t/toshiyan/.conda/envs/loc/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
